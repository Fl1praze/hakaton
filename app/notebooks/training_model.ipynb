# %% [markdown]
# # 🎓 Обучение ML‑модели
#
# Этот notebook показывает **только обучение/дообучение** нашей модели (BERT + классификатор few‑shot).
#
# - используем данные из `app/dataset/raw_texts.json`
# - вызываем готовую функцию `train_model` из `app/train_few_shot_model.py`
# - обучаем 20 эпох
# - показываем финальные метрики и графики.

# %% [markdown]
# ---
# ## 1️⃣ Импорт функции обучения

# %%
import sys
sys.path.append('..')

from train_few_shot_model import train_model
import matplotlib.pyplot as plt

print("✅ Импортировано train_model из app/train_few_shot_model.py")
# Out:
# ✅ Импортировано train_model из app/train_few_shot_model.py

# %% [markdown]
# ---
# ## 2️⃣ Запуск обучения на 20 эпох

# %%
model, history = train_model(epochs=5)

print("\n✅ Обучение завершено (5 эпох)")
print(f"Финальная Val Accuracy: {history['val_acc'][-1]:.3f} ({history['val_acc'][-1]*100:.1f}%)")
# Out:
# ...
# ОБУЧЕНИЕ FEW-SHOT МОДЕЛИ
# ...
# ПОДГОТОВКА ДАННЫХ ДЛЯ FEW-SHOT LEARNING
# ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model, history = train_model(epochs=20)
#       3 print("\n✅ Обучение завершено")
#       4 print(f"Финальная Val Accuracy: {history['val_acc'][-1]:.3f} ({history['val_acc'][-1]*100:.1f}%)")
#
# File ~\PycharmProjects\hakaton\app\notebooks\..\train_few_shot_model.py:204, in train_model(epochs)
#     201 print("="*80)
#     203 # Подготовка данных
# --> 204 texts, labels = prepare_training_data()
#     206 # Разделение на train/val (80/20)
#     207 split_idx = int(len(texts) * 0.8)
#
# File ~\PycharmProjects\hakaton\app\notebooks\..\train_few_shot_model.py:169, in prepare_training_data()
#     167 if not dataset_path.exists():
#     168     dataset_path = Path("app/dataset/raw_texts.json")
# ...

# %% [markdown]
# ---
# ## 3️⃣ Графики loss и accuracy

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 4))

ax1.plot(history['train_loss'], label='Train Loss', marker='o')
ax1.plot(history['val_loss'], label='Val Loss', marker='s')
ax1.set_title('Loss')
ax1.set_xlabel('Epoch')
ax1.legend()
ax1.grid(True, alpha=0.3)

ax2.plot(history['train_acc'], label='Train Acc', marker='o')
ax2.plot(history['val_acc'], label='Val Acc', marker='s')
ax2.set_title('Accuracy')
ax2.set_xlabel('Epoch')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
